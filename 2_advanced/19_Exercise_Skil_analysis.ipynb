# %%
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_Da_Usa = df[((df['job_country'] == 'United States')  & (df['job_title_short'] == 'Data Analyst'))].copy()
df_Da_Usa= df_Da_Usa.dropna(subset=['salary_year_avg'])

# %%
df_Da_Usa
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %%
df_Da_Usa.explode('job_skills')
# Out:
#        job_title_short                              job_title   job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 180       Data Analyst                       Data Analyst III  Dos Palos, CA
# ...                ...                                    ...            ...
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
#
# ...

# %%
df_Da_Usa= df_Da_Usa.explode('job_skills')

df_Da_Usa[['job_skills','salary_year_avg']]
# Out:
#        job_skills  salary_year_avg
# 109        python          89000.0
# 109             r          89000.0
# 109       alteryx          89000.0
# 109       tableau          89000.0
# 180         excel          90250.0
# ...           ...              ...
# 784882        sql          87500.0
# 784882        vba          87500.0
# 784882    tableau          87500.0
# 784882      excel          87500.0
# 784882    alteryx          87500.0
#
# [17440 rows x 2 columns]

# %%
df_DA_US_group = df_Da_Usa.groupby('job_skills')['salary_year_avg'].agg(['count','median'])

df_DA_US_top_pay = df_DA_US_group.sort_values(by='median', ascending=False).head(10)

df_DA_skills = df_DA_US_group.sort_values(by='count', ascending=False).head(10).sort_values(by='median', ascending=False)

# %%
fig, ax =plt.subplots(2,1, figsize=(15,10))

df_DA_US_top_pay.plot(kind='barh', y='median', ax=ax[0], color='skyblue', title='Top 10 Skills for Data Analysts',legend=False)
ax[0].invert_yaxis()
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int (x/1000)}K'))

df_DA_skills.plot(kind='barh', y='median', ax=ax[1], color='lightgreen', title='Top 10 most In-Demand skills for Data Analysts',legend=False)
ax[1].invert_yaxis()
ax[1].set_xlim(ax[0].get_xlim())
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary in $USD')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int (x/1000)}K'))
fig.tight_layout()
