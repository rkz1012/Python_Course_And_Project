# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(13, random_state= 32)
# Out:
#               job_title_short  \
# 726955           Data Analyst
# 640874           Data Analyst
# 133115       Business Analyst
# 231903  Senior Data Scientist
# 511218      Software Engineer
# 770498         Data Scientist
# 408161          Data Engineer
# 61685       Software Engineer
# 496542       Business Analyst
# 1856           Data Scientist
# 113974       Business Analyst
# 254928    Senior Data Analyst
# 248480   Senior Data Engineer
#
#                                                 job_title  \
# 726955                                       Data Analyst
# 640874                                        Market Data
# 133115                                     Growth Analyst
# 231903                       Senior Manager, Data Science
# 511218  Re-advertisement: Senior Systems Analyst (24 M...
# 770498                        Data Scientist - Shuzhao Li
# 408161                                Cloud Data Engineer
# 61685                                         IT Engineer
# 496542                                Analist indicatoren
# 1856    Data Scientist III - Product Lifecycle & Inter...
# 113974                                  Marketing Analyst
# 254928                        Data Quality Senior Analyst
# 248480                      Analista Senior Data Engineer
#
#                     job_location                   job_via job_schedule_type  \
# 726955               Atlanta, GA              via LinkedIn         Full-time
# 640874            Kraków, Poland           via Trabajo.org         Full-time
# 133115                     Spain              via LinkedIn         Full-time
# 231903                McLean, VA           via Trabajo.org         Full-time
# 511218              Saudi Arabia  via Jobs In South Africa         Full-time
# 770498            Farmington, CT              via LinkedIn         Full-time
# 408161                     India           via BeBee India         Full-time
# 61685   Bogotá, Bogota, Colombia                 via BeBee         Full-time
# 496542         Brussels, Belgium        via BeBee Belgique         Full-time
# 1856            Barcelona, Spain              via LinkedIn         Full-time
# 113974                  Anywhere                via Indeed         Full-time
# 254928                  Portugal        via BeBee Portugal         Full-time
# 248480                Lima, Peru            via BeBee Perú         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 726955               False                  Georgia 2023-06-08 21:46:27
# 640874               False                   Poland 2023-02-14 12:37:43
# 133115               False                    Spain 2023-07-14 08:22:56
# 231903               False  New York, United States 2023-10-25 07:03:26
# 511218               False             Saudi Arabia 2023-06-27 11:42:23
# 770498               False  New York, United States 2023-01-26 01:03:06
# 408161               False                    India 2023-05-16 16:17:10
# 61685                False                 Colombia 2023-08-23 06:28:09
# 496542               False                  Belgium 2023-10-09 11:50:37
# 1856                 False                    Spain 2023-03-07 13:44:13
# 113974                True                   Canada 2023-04-12 00:55:17
# 254928               False                 Portugal 2023-08-30 07:28:43
# 248480               False                     Peru 2023-11-18 07:31:35
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 726955                  False                 False  United States
# 640874                   True                 False         Poland
# 133115                   True                 False          Spain
# 231903                  False                 False  United States
# 511218                  False                 False   Saudi Arabia
# 770498                  False                 False  United States
# 408161                  False                 False          India
# 61685                    True                 False       Colombia
# 496542                  False                 False        Belgium
# 1856                    False                 False          Spain
# 113974                  False                 False         Canada
# 254928                   True                 False       Portugal
# 248480                  False                 False           Peru
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 726955        None              NaN              NaN
# 640874        None              NaN              NaN
# 133115        None              NaN              NaN
# 231903        None              NaN              NaN
# 511218        None              NaN              NaN
# 770498        None              NaN              NaN
# 408161        None              NaN              NaN
# 61685         None              NaN              NaN
# 496542        None              NaN              NaN
# 1856          None              NaN              NaN
# 113974        None              NaN              NaN
# 254928        None              NaN              NaN
# 248480        None              NaN              NaN
#
#                           company_name  \
# 726955                 Troutman Pepper
# 640874  Grafton Recruitment Sp. z o.o.
# 133115               Indicia Worldwide
# 231903                      Cognosante
# 511218                      Rand Water
# 770498          The Jackson Laboratory
# 408161                        Ericsson
# 61685                     jobandtalent
# 496542                         Actiris
# 1856                    Teladoc Health
# 113974                   Apply Digital
# 254928                     Bnp Paribas
# 248480                         Emprego
#
#                                                job_skills  \
# 726955  ['sql', 'python', 'r', 'sql server', 'azure', ...
# 640874                                     ['c', 'linux']
# 133115                      ['html', 'css', 'javascript']
# 231903                                               None
# 511218                                  ['oracle', 'sap']
# 770498                                    ['python', 'r']
# 408161  ['shell', 'scala', 'python', 'java', 'airflow'...
# 61685                    ['sql', 'go', 'mysql', 'oracle']
# 496542                                               None
# 1856    ['python', 'sql', 'pytorch', 'tensorflow', 'sp...
# 113974                                            ['sql']
# 254928                                               None
# 248480                       ['sql', 'azure', 'power bi']
#
#                                           job_type_skills
# 726955  {'analyst_tools': ['power bi', 'alteryx', 'exc...
# 640874            {'os': ['linux'], 'programming': ['c']}
# 133115     {'programming': ['html', 'css', 'javascript']}
# 231903                                               None
# 511218    {'analyst_tools': ['sap'], 'cloud': ['oracle']}
# 770498                   {'programming': ['python', 'r']}
# 408161  {'libraries': ['airflow', 'pyspark', 'spark', ...
# 61685   {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 496542                                               None
# 1856    {'libraries': ['pytorch', 'tensorflow', 'spark...
# 113974                           {'programming': ['sql']}
# 254928                                               None
# 248480  {'analyst_tools': ['power bi'], 'cloud': ['azu...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_orginal = dataset['train'].to_pandas()

# %%
df_altered = df_orginal.copy()
